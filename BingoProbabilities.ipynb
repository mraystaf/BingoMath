# %%
import numpy as np
from itertools import combinations
import math

# %%
# Testing the validity of the X* function. # TODO: It's wrong
def P_x_star(k):
    #return (12*math.factorial(20) / math.factorial(25)) * (math.factorial(k) / math.factorial(k-5))
    return 12*math.comb(20,k-5) / math.comb(25,k)

# %%
for i in range(math.comb(25,12)):
    P_x_star(12)

print("Done")
# Out:
# Done
